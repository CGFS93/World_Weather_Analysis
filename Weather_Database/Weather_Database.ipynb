# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 770

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 3 of Set 1 | lincoln
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | uyar
# Processing Record 7 of Set 1 | san jeronimo
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | banon
# Processing Record 12 of Set 1 | kawalu
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | samusu
# City not found. Skipping
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | grants
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | ormara
# Processing Record 22 of Set 1 | eldorado
# Processing Record 23 of Set 1 | hualmay
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | rantepao
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | katherine
# Processing Record 30 of Set 1 | port hedland
# Processing Record 31 of Set 1 | nabire
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | ucluelet
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | umzimvubu
# City not found. Skipping
# Processing Record 42 of Set 1 | ferrol
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | margate
# Processing Record 46 of Set 1 | puerto baquerizo moreno
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | nemuro
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | caidian
# Processing Record 5 of Set 2 | basco
# Processing Record 6 of Set 2 | hof
# Processing Record 7 of Set 2 | vallenar
# Processing Record 8 of Set 2 | wad madani
# Processing Record 9 of Set 2 | san quintin
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | svencionys
# Processing Record 12 of Set 2 | preston
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping
# Processing Record 15 of Set 2 | mutsamudu
# City not found. Skipping
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | iquique
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | faanui
# Processing Record 22 of Set 2 | zhigansk
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | hambantota
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | port-cartier
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | ekibastuz
# Processing Record 30 of Set 2 | aswan
# Processing Record 31 of Set 2 | senneterre
# Processing Record 32 of Set 2 | kautokeino
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | panguna
# Processing Record 36 of Set 2 | hobyo
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | mackay
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | longlac
# City not found. Skipping
# Processing Record 42 of Set 2 | dawlatabad
# Processing Record 43 of Set 2 | can tho
# Processing Record 44 of Set 2 | key largo
# Processing Record 45 of Set 2 | oksfjord
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | ushuaia
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 50 of Set 2 | salalah
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | garowe
# Processing Record 3 of Set 3 | vostok
# Processing Record 4 of Set 3 | cockburn town
# Processing Record 5 of Set 3 | berlevag
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping
# Processing Record 8 of Set 3 | raahe
# Processing Record 9 of Set 3 | taga
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | dingzhou
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | manokwari
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | port augusta
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | santa maria
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | bodden town
# Processing Record 23 of Set 3 | ambon
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | bargal
# City not found. Skipping
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | lazaro cardenas
# Processing Record 28 of Set 3 | makakilo city
# Processing Record 29 of Set 3 | jiexiu
# Processing Record 30 of Set 3 | cozumel
# Processing Record 31 of Set 3 | jauja
# Processing Record 32 of Set 3 | ketchikan
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | jutai
# Processing Record 36 of Set 3 | lexington
# Processing Record 37 of Set 3 | puerto escondido
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | tuburan
# Processing Record 42 of Set 3 | bebedouro
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | hun
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | yumen
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | brownsville
# Processing Record 49 of Set 3 | kinanah
# City not found. Skipping
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | ostrovnoy
# Processing Record 2 of Set 4 | panaba
# Processing Record 3 of Set 4 | sulangan
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | olafsvik
# Processing Record 7 of Set 4 | fort saint john
# City not found. Skipping
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 9 of Set 4 | cape town
# Processing Record 10 of Set 4 | kudahuvadhoo
# Processing Record 11 of Set 4 | ust-kulom
# Processing Record 12 of Set 4 | egvekinot
# Processing Record 13 of Set 4 | sola
# Processing Record 14 of Set 4 | najran
# Processing Record 15 of Set 4 | lakatoro
# Processing Record 16 of Set 4 | xining
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | mirnyy
# Processing Record 19 of Set 4 | baykit
# Processing Record 20 of Set 4 | alamogordo
# Processing Record 21 of Set 4 | aykhal
# Processing Record 22 of Set 4 | lensk
# Processing Record 23 of Set 4 | muzquiz
# City not found. Skipping
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | paralimni
# Processing Record 27 of Set 4 | fayetteville
# Processing Record 28 of Set 4 | beyneu
# Processing Record 29 of Set 4 | ruatoria
# City not found. Skipping
# Processing Record 30 of Set 4 | timra
# Processing Record 31 of Set 4 | anloga
# Processing Record 32 of Set 4 | izumo
# Processing Record 33 of Set 4 | nouadhibou
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | zaporizhzhya
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | spornoye
# Processing Record 42 of Set 4 | noumea
# Processing Record 43 of Set 4 | illoqqortoormiut
# City not found. Skipping
# Processing Record 44 of Set 4 | mnogovershinnyy
# Processing Record 45 of Set 4 | piacabucu
# Processing Record 46 of Set 4 | starachowice
# Processing Record 47 of Set 4 | simao
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | kajaani
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | anori
# Processing Record 3 of Set 5 | tahe
# Processing Record 4 of Set 5 | high level
# Processing Record 5 of Set 5 | capinzal
# Processing Record 6 of Set 5 | rocha
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | potgietersrus
# City not found. Skipping
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | poso
# Processing Record 11 of Set 5 | mmathubudukwane
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | chapais
# Processing Record 14 of Set 5 | dzan
# Processing Record 15 of Set 5 | ukiah
# Processing Record 16 of Set 5 | lamballe
# Processing Record 17 of Set 5 | pichayevo
# Processing Record 18 of Set 5 | comodoro rivadavia
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | nguiu
# City not found. Skipping
# Processing Record 22 of Set 5 | taoudenni
# Processing Record 23 of Set 5 | beni
# Processing Record 24 of Set 5 | nuuk
# Processing Record 25 of Set 5 | mikhaylovskoye
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | imbituba
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | fukue
# Processing Record 31 of Set 5 | conde
# Processing Record 32 of Set 5 | bogo
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | mpongwe
# Processing Record 35 of Set 5 | brenham
# Processing Record 36 of Set 5 | cabedelo
# Processing Record 37 of Set 5 | kaeo
# Processing Record 38 of Set 5 | shimanovsk
# Processing Record 39 of Set 5 | soyo
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | nara
# Processing Record 42 of Set 5 | zhangye
# Processing Record 43 of Set 5 | mys shmidta
# City not found. Skipping
# Processing Record 44 of Set 5 | mlonggo
# Processing Record 45 of Set 5 | kitui
# Processing Record 46 of Set 5 | saint-augustin
# Processing Record 47 of Set 5 | tadine
# Processing Record 48 of Set 5 | angoche
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | nagato
# Processing Record 1 of Set 6 | pindushi
# Processing Record 2 of Set 6 | barrow
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | zdvinsk
# Processing Record 5 of Set 6 | akureyri
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | kayiry
# Processing Record 8 of Set 6 | geresk
# City not found. Skipping
# Processing Record 9 of Set 6 | borzya
# Processing Record 10 of Set 6 | tecoanapa
# Processing Record 11 of Set 6 | laguna
# Processing Record 12 of Set 6 | touba
# Processing Record 13 of Set 6 | soe
# Processing Record 14 of Set 6 | samarai
# Processing Record 15 of Set 6 | nicoya
# Processing Record 16 of Set 6 | biltine
# Processing Record 17 of Set 6 | dresden
# Processing Record 18 of Set 6 | labuhan
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | pacific grove
# Processing Record 22 of Set 6 | domat
# Processing Record 23 of Set 6 | llata
# Processing Record 24 of Set 6 | sur
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | destin
# Processing Record 27 of Set 6 | gambiran
# Processing Record 28 of Set 6 | souillac
# Processing Record 29 of Set 6 | shenzhen
# Processing Record 30 of Set 6 | ballina
# Processing Record 31 of Set 6 | bonwapitse
# Processing Record 32 of Set 6 | severo-kurilsk
# Processing Record 33 of Set 6 | arrifes
# Processing Record 34 of Set 6 | nelson bay
# Processing Record 35 of Set 6 | derzhavinsk
# Processing Record 36 of Set 6 | tongzi
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | marcona
# City not found. Skipping
# Processing Record 39 of Set 6 | ossora
# Processing Record 40 of Set 6 | wahran
# City not found. Skipping
# Processing Record 41 of Set 6 | ayan
# Processing Record 42 of Set 6 | nashville
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | machali
# Processing Record 45 of Set 6 | mentor
# Processing Record 46 of Set 6 | whitehorse
# Processing Record 47 of Set 6 | okha
# Processing Record 48 of Set 6 | mendahara
# City not found. Skipping
# Processing Record 49 of Set 6 | east london
# Processing Record 50 of Set 6 | phan thiet
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | falealupo
# City not found. Skipping
# Processing Record 6 of Set 7 | nyurba
# Processing Record 7 of Set 7 | juba
# Processing Record 8 of Set 7 | batagay-alyta
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | ciudad bolivar
# Processing Record 12 of Set 7 | la reforma
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | samalaeulu
# City not found. Skipping
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | lagos
# Processing Record 17 of Set 7 | amapa
# Processing Record 18 of Set 7 | oriximina
# Processing Record 19 of Set 7 | takoradi
# Processing Record 20 of Set 7 | yeppoon
# Processing Record 21 of Set 7 | qasigiannguit
# Processing Record 22 of Set 7 | bad freienwalde
# Processing Record 23 of Set 7 | mareeba
# Processing Record 24 of Set 7 | verkhoyansk
# Processing Record 25 of Set 7 | road town
# Processing Record 26 of Set 7 | bilibino
# Processing Record 27 of Set 7 | skibbereen
# Processing Record 28 of Set 7 | solvychegodsk
# Processing Record 29 of Set 7 | sungairaya
# Processing Record 30 of Set 7 | waingapu
# Processing Record 31 of Set 7 | luwuk
# Processing Record 32 of Set 7 | kuusamo
# Processing Record 33 of Set 7 | te anau
# Processing Record 34 of Set 7 | lucapa
# Processing Record 35 of Set 7 | cidreira
# Processing Record 36 of Set 7 | kenitra
# Processing Record 37 of Set 7 | el alto
# Processing Record 38 of Set 7 | kijang
# Processing Record 39 of Set 7 | kailua
# Processing Record 40 of Set 7 | grand river south east
# City not found. Skipping
# Processing Record 41 of Set 7 | cacapava do sul
# Processing Record 42 of Set 7 | vanavara
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | sesheke
# Processing Record 45 of Set 7 | bose
# Processing Record 46 of Set 7 | jawhar
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | amderma
# City not found. Skipping
# Processing Record 49 of Set 7 | tiarei
# Processing Record 50 of Set 7 | kirknewton
# Processing Record 1 of Set 8 | garissa
# Processing Record 2 of Set 8 | poum
# Processing Record 3 of Set 8 | olinda
# Processing Record 4 of Set 8 | sisimiut
# Processing Record 5 of Set 8 | vestmannaeyjar
# Processing Record 6 of Set 8 | aden
# Processing Record 7 of Set 8 | kyshtovka
# Processing Record 8 of Set 8 | pesochenskiy
# Processing Record 9 of Set 8 | pringsewu
# Processing Record 10 of Set 8 | gazni
# City not found. Skipping
# Processing Record 11 of Set 8 | puerto penasco
# Processing Record 12 of Set 8 | maravilha
# Processing Record 13 of Set 8 | saint-pierre
# Processing Record 14 of Set 8 | coquimbo
# Processing Record 15 of Set 8 | porto novo
# Processing Record 16 of Set 8 | rio rancho
# Processing Record 17 of Set 8 | marawi
# Processing Record 18 of Set 8 | tocopilla
# Processing Record 19 of Set 8 | bambous virieux
# Processing Record 20 of Set 8 | tiznit
# Processing Record 21 of Set 8 | ambulu
# Processing Record 22 of Set 8 | serebryansk
# Processing Record 23 of Set 8 | alpena
# Processing Record 24 of Set 8 | mouzakion
# City not found. Skipping
# Processing Record 25 of Set 8 | doha
# Processing Record 26 of Set 8 | kinshasa
# Processing Record 27 of Set 8 | sorvag
# City not found. Skipping
# Processing Record 28 of Set 8 | warqla
# City not found. Skipping
# Processing Record 29 of Set 8 | krasnoselkup
# Processing Record 30 of Set 8 | finspang
# Processing Record 31 of Set 8 | leningradskiy
# Processing Record 32 of Set 8 | bokspits
# City not found. Skipping
# Processing Record 33 of Set 8 | toktogul
# Processing Record 34 of Set 8 | cabo san lucas
# Processing Record 35 of Set 8 | paracale
# Processing Record 36 of Set 8 | port hardy
# Processing Record 37 of Set 8 | paciran
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | soligalich
# Processing Record 40 of Set 8 | hohhot
# Processing Record 41 of Set 8 | lillehammer
# Processing Record 42 of Set 8 | wad rawah
# Processing Record 43 of Set 8 | rorvik
# Processing Record 44 of Set 8 | puerto quijarro
# Processing Record 45 of Set 8 | roberto payan
# City not found. Skipping
# Processing Record 46 of Set 8 | lesnoy
# Processing Record 47 of Set 8 | dekar
# Processing Record 48 of Set 8 | iisalmi
# Processing Record 49 of Set 8 | brae
# Processing Record 50 of Set 8 | agaro
# Processing Record 1 of Set 9 | belmonte
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | horodyshche
# Processing Record 4 of Set 9 | guatire
# Processing Record 5 of Set 9 | tabukiniberu
# City not found. Skipping
# Processing Record 6 of Set 9 | nanortalik
# Processing Record 7 of Set 9 | toliary
# City not found. Skipping
# Processing Record 8 of Set 9 | careiro da varzea
# Processing Record 9 of Set 9 | tsybli
# Processing Record 10 of Set 9 | dulyapino
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | oum hadjer
# Processing Record 13 of Set 9 | tiksi
# Processing Record 14 of Set 9 | san policarpo
# Processing Record 15 of Set 9 | khasan
# Processing Record 16 of Set 9 | south yuba city
# Processing Record 17 of Set 9 | inverness
# Processing Record 18 of Set 9 | mouila
# Processing Record 19 of Set 9 | acapulco
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | prieska
# Processing Record 22 of Set 9 | provideniya
# Processing Record 23 of Set 9 | coswig
# Processing Record 24 of Set 9 | maragogi
# Processing Record 25 of Set 9 | pemangkat
# Processing Record 26 of Set 9 | payo
# Processing Record 27 of Set 9 | moratuwa
# Processing Record 28 of Set 9 | santa isabel do rio negro
# Processing Record 29 of Set 9 | jardim
# Processing Record 30 of Set 9 | mpanda
# Processing Record 31 of Set 9 | mercedes
# Processing Record 32 of Set 9 | kaitangata
# Processing Record 33 of Set 9 | chegdomyn
# Processing Record 34 of Set 9 | los llanos de aridane
# Processing Record 35 of Set 9 | kiunga
# Processing Record 36 of Set 9 | yanan
# City not found. Skipping
# Processing Record 37 of Set 9 | batemans bay
# Processing Record 38 of Set 9 | dalhousie
# Processing Record 39 of Set 9 | ushtobe
# Processing Record 40 of Set 9 | uray
# Processing Record 41 of Set 9 | niscemi
# Processing Record 42 of Set 9 | buraydah
# Processing Record 43 of Set 9 | chapleau
# Processing Record 44 of Set 9 | alta floresta
# Processing Record 45 of Set 9 | banepa
# Processing Record 46 of Set 9 | panhala
# Processing Record 47 of Set 9 | ayagoz
# Processing Record 48 of Set 9 | iturama
# Processing Record 49 of Set 9 | bereda
# Processing Record 50 of Set 9 | ambilobe
# Processing Record 1 of Set 10 | sambava
# Processing Record 2 of Set 10 | bandarbeyla
# Processing Record 3 of Set 10 | zambrow
# Processing Record 4 of Set 10 | kichera
# Processing Record 5 of Set 10 | kumluca
# Processing Record 6 of Set 10 | bonthe
# Processing Record 7 of Set 10 | vilyuysk
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | tomohon
# Processing Record 10 of Set 10 | grand forks
# Processing Record 11 of Set 10 | ramsar
# Processing Record 12 of Set 10 | victor harbor
# Processing Record 13 of Set 10 | arraias
# Processing Record 14 of Set 10 | ler
# Processing Record 15 of Set 10 | mustasaari
# Processing Record 16 of Set 10 | verkhnevilyuysk
# Processing Record 17 of Set 10 | linfen
# Processing Record 18 of Set 10 | kourou
# Processing Record 19 of Set 10 | ostersund
# Processing Record 20 of Set 10 | rebricea
# Processing Record 21 of Set 10 | ayr
# Processing Record 22 of Set 10 | wangqing
# Processing Record 23 of Set 10 | skelleftea
# Processing Record 24 of Set 10 | walla walla
# Processing Record 25 of Set 10 | komsomolskiy
# Processing Record 26 of Set 10 | honiara
# Processing Record 27 of Set 10 | bonavista
# Processing Record 28 of Set 10 | sinkat
# City not found. Skipping
# Processing Record 29 of Set 10 | birjand
# Processing Record 30 of Set 10 | ngukurr
# City not found. Skipping
# Processing Record 31 of Set 10 | killybegs
# Processing Record 32 of Set 10 | cape coast
# Processing Record 33 of Set 10 | antsohihy
# Processing Record 34 of Set 10 | eskasem
# City not found. Skipping
# Processing Record 35 of Set 10 | guerrero negro
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | cap malheureux
# Processing Record 38 of Set 10 | sao joao da barra
# Processing Record 39 of Set 10 | eenhana
# Processing Record 40 of Set 10 | pevek
# Processing Record 41 of Set 10 | sao miguel do araguaia
# Processing Record 42 of Set 10 | pestovo
# Processing Record 43 of Set 10 | torrevieja
# Processing Record 44 of Set 10 | emet
# Processing Record 45 of Set 10 | campbell river
# Processing Record 46 of Set 10 | broken hill
# Processing Record 47 of Set 10 | duz
# City not found. Skipping
# Processing Record 48 of Set 10 | gidam
# Processing Record 49 of Set 10 | xichang
# Processing Record 50 of Set 10 | ishigaki
# Processing Record 1 of Set 11 | dudinka
# Processing Record 2 of Set 11 | saint-paul
# Processing Record 3 of Set 11 | iralaya
# Processing Record 4 of Set 11 | yaan
# Processing Record 5 of Set 11 | harper
# Processing Record 6 of Set 11 | elsterwerda
# Processing Record 7 of Set 11 | santa isabel
# Processing Record 8 of Set 11 | wamba
# Processing Record 9 of Set 11 | paso de los toros
# Processing Record 10 of Set 11 | new lenox
# Processing Record 11 of Set 11 | sorong
# Processing Record 12 of Set 11 | koga
# Processing Record 13 of Set 11 | barentu
# Processing Record 14 of Set 11 | ondorhaan
# City not found. Skipping
# Processing Record 15 of Set 11 | kupang
# Processing Record 16 of Set 11 | banda aceh
# Processing Record 17 of Set 11 | hangu
# Processing Record 18 of Set 11 | baker city
# Processing Record 19 of Set 11 | teahupoo
# Processing Record 20 of Set 11 | bull savanna
# Processing Record 21 of Set 11 | valdivia
# Processing Record 22 of Set 11 | brainerd
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | plouzane
# Processing Record 25 of Set 11 | kamenka
# Processing Record 26 of Set 11 | qaqortoq
# Processing Record 27 of Set 11 | shingu
# Processing Record 28 of Set 11 | teya
# Processing Record 29 of Set 11 | luganville
# Processing Record 30 of Set 11 | kieta
# Processing Record 31 of Set 11 | zanjan
# Processing Record 32 of Set 11 | pitimbu
# Processing Record 33 of Set 11 | tucupita
# Processing Record 34 of Set 11 | aktash
# Processing Record 35 of Set 11 | marsa matruh
# Processing Record 36 of Set 11 | magog
# Processing Record 37 of Set 11 | nikolayevskaya
# Processing Record 38 of Set 11 | kasane
# Processing Record 39 of Set 11 | neiafu
# Processing Record 40 of Set 11 | kattivakkam
# Processing Record 41 of Set 11 | passagem franca
# Processing Record 42 of Set 11 | muscat
# Processing Record 43 of Set 11 | palabuhanratu
# City not found. Skipping
# Processing Record 44 of Set 11 | flinders
# Processing Record 45 of Set 11 | yongchang
# Processing Record 46 of Set 11 | ratnagiri
# Processing Record 47 of Set 11 | zhezkazgan
# Processing Record 48 of Set 11 | kiruna
# Processing Record 49 of Set 11 | westport
# Processing Record 50 of Set 11 | saint albans
# Processing Record 1 of Set 12 | halifax
# Processing Record 2 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 12 | tabiauea
# City not found. Skipping
# Processing Record 4 of Set 12 | soller
# Processing Record 5 of Set 12 | luwingu
# Processing Record 6 of Set 12 | palu
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | ocampo
# Processing Record 9 of Set 12 | macaboboni
# City not found. Skipping
# Processing Record 10 of Set 12 | maghama
# City not found. Skipping
# Processing Record 11 of Set 12 | ati
# Processing Record 12 of Set 12 | chake chake
# Processing Record 13 of Set 12 | nayoro
# Processing Record 14 of Set 12 | ambodifototra
# City not found. Skipping
# Processing Record 15 of Set 12 | mitsamiouli
# Processing Record 16 of Set 12 | yirol
# City not found. Skipping
# Processing Record 17 of Set 12 | vilhena
# Processing Record 18 of Set 12 | ankang
# Processing Record 19 of Set 12 | murgab
# Processing Record 20 of Set 12 | mehamn
# Processing Record 21 of Set 12 | pabrade
# Processing Record 22 of Set 12 | yinchuan
# Processing Record 23 of Set 12 | sao felix do xingu
# Processing Record 24 of Set 12 | ulladulla
# Processing Record 25 of Set 12 | machiques
# Processing Record 26 of Set 12 | hue
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | skagastrond
# City not found. Skipping
# Processing Record 29 of Set 12 | moshenskoye
# Processing Record 30 of Set 12 | pinawa
# Processing Record 31 of Set 12 | huntsville
# Processing Record 32 of Set 12 | semnan
# Processing Record 33 of Set 12 | moose factory
# Processing Record 34 of Set 12 | spokane
# Processing Record 35 of Set 12 | gisborne
# Processing Record 36 of Set 12 | qandala
# Processing Record 37 of Set 12 | gwanda
# Processing Record 38 of Set 12 | angoram
# Processing Record 39 of Set 12 | santa cruz
# Processing Record 40 of Set 12 | lufilufi
# Processing Record 41 of Set 12 | itarema
# Processing Record 42 of Set 12 | mahibadhoo
# Processing Record 43 of Set 12 | riyaq
# City not found. Skipping
# Processing Record 44 of Set 12 | skalistyy
# City not found. Skipping
# Processing Record 45 of Set 12 | karratha
# Processing Record 46 of Set 12 | sayat
# Processing Record 47 of Set 12 | usilampatti
# Processing Record 48 of Set 12 | vicosa do ceara
# Processing Record 49 of Set 12 | tokur
# Processing Record 50 of Set 12 | shetpe
# Processing Record 1 of Set 13 | viligili
# City not found. Skipping
# Processing Record 2 of Set 13 | zemio
# Processing Record 3 of Set 13 | carutapera
# Processing Record 4 of Set 13 | luanda
# Processing Record 5 of Set 13 | araouane
# Processing Record 6 of Set 13 | mirebalais
# Processing Record 7 of Set 13 | maamba
# Processing Record 8 of Set 13 | yunjinghong
# City not found. Skipping
# Processing Record 9 of Set 13 | hihifo
# City not found. Skipping
# Processing Record 10 of Set 13 | constantine
# Processing Record 11 of Set 13 | santa lucia
# Processing Record 12 of Set 13 | haines junction
# Processing Record 13 of Set 13 | sao sebastiao
# Processing Record 14 of Set 13 | talavera de la reina
# Processing Record 15 of Set 13 | baracoa
# Processing Record 16 of Set 13 | mahajanga
# Processing Record 17 of Set 13 | alice springs
# Processing Record 18 of Set 13 | nouakchott
# Processing Record 19 of Set 13 | urucara
# Processing Record 20 of Set 13 | kabo
# Processing Record 21 of Set 13 | andujar
# Processing Record 22 of Set 13 | kyren
# Processing Record 23 of Set 13 | marienburg
# Processing Record 24 of Set 13 | saint anthony
# Processing Record 25 of Set 13 | severo-yeniseyskiy
# Processing Record 26 of Set 13 | wodonga
# Processing Record 27 of Set 13 | altayskoye
# Processing Record 28 of Set 13 | businga
# Processing Record 29 of Set 13 | boa vista
# Processing Record 30 of Set 13 | skjervoy
# Processing Record 31 of Set 13 | santa vitoria do palmar
# Processing Record 32 of Set 13 | biak
# Processing Record 33 of Set 13 | paka
# Processing Record 34 of Set 13 | san jose
# Processing Record 35 of Set 13 | saint-francois
# Processing Record 36 of Set 13 | saint-georges
# Processing Record 37 of Set 13 | kaihua
# Processing Record 38 of Set 13 | winnemucca
# Processing Record 39 of Set 13 | saint-joseph
# Processing Record 40 of Set 13 | alpinopolis
# Processing Record 41 of Set 13 | antofagasta
# Processing Record 42 of Set 13 | fare
# Processing Record 43 of Set 13 | lata
# Processing Record 44 of Set 13 | diego de almagro
# Processing Record 45 of Set 13 | vestmanna
# Processing Record 46 of Set 13 | isiro
# Processing Record 47 of Set 13 | arman
# Processing Record 48 of Set 13 | bolungarvik
# City not found. Skipping
# Processing Record 49 of Set 13 | kavarna
# Processing Record 50 of Set 13 | palora
# Processing Record 1 of Set 14 | blagoyevo
# Processing Record 2 of Set 14 | kirakira
# Processing Record 3 of Set 14 | vaitape
# Processing Record 4 of Set 14 | manicore
# Processing Record 5 of Set 14 | gat
# Processing Record 6 of Set 14 | bestobe
# Processing Record 7 of Set 14 | tagusao
# Processing Record 8 of Set 14 | kalashnikovo
# Processing Record 9 of Set 14 | port blair
# Processing Record 10 of Set 14 | manono
# Processing Record 11 of Set 14 | berck
# Processing Record 12 of Set 14 | tanete
# Processing Record 13 of Set 14 | vila
# Processing Record 14 of Set 14 | north bend
# Processing Record 15 of Set 14 | yulara
# Processing Record 16 of Set 14 | tulle
# Processing Record 17 of Set 14 | pangnirtung
# Processing Record 18 of Set 14 | ahumada
# City not found. Skipping
# Processing Record 19 of Set 14 | campina verde
# Processing Record 20 of Set 14 | athens
# Processing Record 21 of Set 14 | bam
# Processing Record 22 of Set 14 | ahipara
# Processing Record 23 of Set 14 | vanimo
# Processing Record 24 of Set 14 | hirara
# Processing Record 25 of Set 14 | alappuzha
# Processing Record 26 of Set 14 | castletown
# Processing Record 27 of Set 14 | salinas
# Processing Record 28 of Set 14 | tortoli
# Processing Record 29 of Set 14 | yangjiang
# Processing Record 30 of Set 14 | visby
# Processing Record 31 of Set 14 | shubarkuduk
# Processing Record 32 of Set 14 | sayyan
# Processing Record 33 of Set 14 | kavaratti
# Processing Record 34 of Set 14 | lubango
# Processing Record 35 of Set 14 | spas-demensk
# Processing Record 36 of Set 14 | sao joaquim
# Processing Record 37 of Set 14 | fukuma
# Processing Record 38 of Set 14 | polovinnoye
# Processing Record 39 of Set 14 | goderich
# Processing Record 40 of Set 14 | kuvandyk
# Processing Record 41 of Set 14 | ailigandi
# Processing Record 42 of Set 14 | levashovo
# Processing Record 43 of Set 14 | college
# Processing Record 44 of Set 14 | gamba
# Processing Record 45 of Set 14 | tautira
# Processing Record 46 of Set 14 | cam ranh
# Processing Record 47 of Set 14 | auki
# Processing Record 48 of Set 14 | bolanos de calatrava
# Processing Record 49 of Set 14 | festus
# Processing Record 50 of Set 14 | shitanjing
# Processing Record 1 of Set 15 | kutum
# Processing Record 2 of Set 15 | darlowo
# Processing Record 3 of Set 15 | changji
# Processing Record 4 of Set 15 | sabzevar
# Processing Record 5 of Set 15 | ibra
# Processing Record 6 of Set 15 | manacapuru
# Processing Record 7 of Set 15 | irbid
# Processing Record 8 of Set 15 | coos bay
# Processing Record 9 of Set 15 | moerai
# Processing Record 10 of Set 15 | saurimo
# Processing Record 11 of Set 15 | paytug
# City not found. Skipping
# Processing Record 12 of Set 15 | villarrica
# Processing Record 13 of Set 15 | huambo
# Processing Record 14 of Set 15 | aitape
# Processing Record 15 of Set 15 | frolishchi
# Processing Record 16 of Set 15 | blythe
# Processing Record 17 of Set 15 | millinocket
# Processing Record 18 of Set 15 | abu samrah
# Processing Record 19 of Set 15 | roald
# Processing Record 20 of Set 15 | katsuura
# Processing Record 21 of Set 15 | tessalit
# Processing Record 22 of Set 15 | coihueco
# Processing Record 23 of Set 15 | oranjemund
# Processing Record 24 of Set 15 | shwebo
# Processing Record 25 of Set 15 | tawkar
# City not found. Skipping
# Processing Record 26 of Set 15 | artyk
# City not found. Skipping
# Processing Record 27 of Set 15 | palauig
# Processing Record 28 of Set 15 | rawson
# Processing Record 29 of Set 15 | cacoal
# Processing Record 30 of Set 15 | xingyi
# Processing Record 31 of Set 15 | joao pinheiro
# Processing Record 32 of Set 15 | luza
# Processing Record 33 of Set 15 | aasiaat
# Processing Record 34 of Set 15 | darhan
# Processing Record 35 of Set 15 | goundam
# Processing Record 36 of Set 15 | aksu
# Processing Record 37 of Set 15 | jiblah
# Processing Record 38 of Set 15 | pacasmayo
# Processing Record 39 of Set 15 | martil
# Processing Record 40 of Set 15 | weifang
# Processing Record 41 of Set 15 | beisfjord
# Processing Record 42 of Set 15 | samarkand
# Processing Record 43 of Set 15 | miri
# Processing Record 44 of Set 15 | wuwei
# Processing Record 45 of Set 15 | kyaikto
# Processing Record 46 of Set 15 | narrabri
# Processing Record 47 of Set 15 | satitoa
# City not found. Skipping
# Processing Record 48 of Set 15 | leh
# Processing Record 49 of Set 15 | guangzhou
# Processing Record 50 of Set 15 | japura
# Processing Record 1 of Set 16 | tatawin
# Processing Record 2 of Set 16 | thinadhoo
# Processing Record 3 of Set 16 | porto tolle
# Processing Record 4 of Set 16 | banamba
# Processing Record 5 of Set 16 | vardo
# Processing Record 6 of Set 16 | axim
# Processing Record 7 of Set 16 | svetlaya
# Processing Record 8 of Set 16 | annau
# Processing Record 9 of Set 16 | la libertad
# Processing Record 10 of Set 16 | kalmunai
# Processing Record 11 of Set 16 | west bay
# Processing Record 12 of Set 16 | caraz
# Processing Record 13 of Set 16 | nishihara
# Processing Record 14 of Set 16 | avera
# Processing Record 15 of Set 16 | santa helena de goias
# Processing Record 16 of Set 16 | pozzallo
# Processing Record 17 of Set 16 | praia
# Processing Record 18 of Set 16 | sioux lookout
# Processing Record 19 of Set 16 | yar-sale
# Processing Record 20 of Set 16 | badiraguato
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Busselton      AU  2022-03-27 20:48:11 -33.6500  115.3333     58.08
# 1       Lincoln      US  2022-03-27 20:49:35  40.8000  -96.6670     44.91
# 2        Atuona      PF  2022-03-27 20:52:08  -9.8000 -139.0333     79.23
# 3     Mahebourg      MU  2022-03-27 20:48:33 -20.4081   57.7000     79.09
# 4          Uyar      RU  2022-03-27 20:52:09  55.8100   94.3153      0.21
# 5  San Jeronimo      PE  2022-03-27 20:51:05 -11.9472  -75.2829     60.55
# 6   Clyde River      CA  2022-03-27 20:52:10  70.4692  -68.5914     -1.97
# 7      Hermanus      ZA  2022-03-27 20:52:10 -34.4187   19.2345     68.81
# 8     Namatanai      PG  2022-03-27 20:49:12  -3.6667  152.4333     80.31
# 9         Banon      ES  2022-03-27 20:52:11  40.8382   -1.1909     47.46
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        69           0       13.96           clear sky
# 1        31         100       10.36     overcast clouds
# 2        76          45       14.72    scattered clouds
# 3        83          40        1.14    scattered clouds
# 4        97          37        3.13    scattered clouds
# 5        64          81        4.99       broken clouds
# 6        78         100        8.05     overcast clouds
# 7        67          97        3.98     overcast clouds
# 8        82          98        5.50          light rain
# 9        71           0        6.91           clear sky

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
